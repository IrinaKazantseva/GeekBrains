# %% [markdown]
# <a href="https://colab.research.google.com/github/IrinaKazantseva/Python/blob/main/Seminar3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1.
#
# 1. Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
# 2. Считать данные с помощью pandas
# 3. Вывести на экран первые 5 строк

# %%
import pandas as pd

# %%
df = pd.read_csv('/bin/Sem2/laptops (1).csv', sep=';')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60

# %% [markdown]
# ### 1.1 Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU

# %%
df['Cpu_Company'] = df['Cpu'].apply(lambda x: x.split(' ')[0])
df.sample(frac=0.01)
# Out:
#      Company                              Product            TypeName  Inches  \
# 877   Xiaomi                          Mi Notebook           Ultrabook    13.3
# 1010    Dell                        Inspiron 7567              Gaming    15.6
# 980     Dell                        Inspiron 7579  2 in 1 Convertible    15.6
# 468       HP                      Omen 17-an006nv              Gaming    17.3
# 337       HP                        Elitebook 850            Notebook    15.6
# 1169     MSI                             PL60 7RD              Gaming    15.6
# 547   Lenovo  V310-15ISK (i5-6200U/4GB/1TB/FHD/No            Notebook    15.6
# 967       HP                          ProBook 450            Notebook    15.6
# 1233     MSI                        GE72VR Apache              Gaming    17.3
# 965     Dell                        Inspiron 3567            Notebook    15.6
# 1080  Lenovo                      Yoga 900S-12ISK           Ultrabook    12.5
# 440   Lenovo                    IdeaPad 320-15AST            Notebook    17.3
# 51      Acer                      Aspire A515-51G            Notebook    15.6
#
#                                ScreenResolution                          Cpu  \
# 877                 IPS Panel Full HD 1920x1080   Intel Core i5 6200U 2.3GHz
# 1010                          Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 980   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 468                 IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 337                           Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1169                IPS Panel Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 547                           Full HD 1920x1080   Intel Core i5 6200U 2.3GHz
# 967                           Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# 1233                          Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 965                                    1366x768   Intel Core i3 6006U 2.0GHz
# 1080            IPS Panel Touchscreen 2560x1440     Intel Core M 6Y75 1.2GHz
# 440                                    1600x900    AMD A6-Series 9220 2.5GHz
# 51                  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz
#
#        Ram                Memory                      Gpu       OpSys  Weight  \
# 877    8GB             256GB SSD     Nvidia GeForce 940MX  Windows 10  1.28kg
# 1010   8GB          1.0TB Hybrid  Nvidia GeForce GTX 1050  Windows 10  2.65kg
# 980   12GB             512GB SSD    Intel HD Graphics 620  Windows 10  2.19kg
# 468   12GB               1TB HDD  Nvidia GeForce GTX 1060  Windows 10  3.78kg
# 337    8GB             256GB SSD    Intel HD Graphics 620  Windows 10  1.84kg
# 1169   8GB               1TB HDD  Nvidia GeForce GTX 1050  Windows 10   2.2kg
# 547    4GB               1TB HDD    Intel HD Graphics 520       No OS  2.15kg
# 967    4GB             500GB HDD    Intel HD Graphics 620  Windows 10  2.04kg
# 1233  16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10   2.7kg
# 965    4GB               1TB HDD       AMD Radeon R5 M430       Linux  2.25kg
# 1080   8GB             512GB SSD    Intel HD Graphics 515  Windows 10  0.99kg
# 440    8GB               1TB HDD            AMD Radeon R4  Windows 10   2.8kg
# 51     8GB             256GB SSD     Nvidia GeForce MX150  Windows 10   2.2kg
#
#       Price_euros Cpu_Company
# 877        935.00       Intel
# 1010       949.00       Intel
# 980       1299.00       Intel
# 468       1699.00       Intel
# 337       1144.00       Intel
# 1169       839.00       Intel
# 547        462.35       Intel
# 967        685.00       Intel
# 1233      1598.00       Intel
# 965        465.62       Intel
# 1080      1399.00       Intel
# 440        519.00         AMD
# 51         841.00       Intel

# %% [markdown]
# ### 1.2 Создать новый признак Memory_Amount, который будет содержать только количество Gb памяти без указания типа носителя

# %%
def convert_to_gb(x):
    memory = x.split(' ')[0]
    if memory.endswith('GB'):
        res = memory.replace('GB', '')
    elif memory.endswith('TB'):
        res = float(memory.replace('TB', '')) * 1024
    return int(res)

# %%
df['Memory_Amount'] = df['Memory'].apply(convert_to_gb)
df.tail()
# Out:
#      Company                              Product            TypeName  Inches  \
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                         Gpu       OpSys  Weight  Price_euros Cpu_Company  \
# 1298  Intel HD Graphics 520  Windows 10   1.8kg        638.0       Intel
# 1299  Intel HD Graphics 520  Windows 10   1.3kg       1499.0       Intel
# 1300      Intel HD Graphics  Windows 10   1.5kg        229.0       Intel
# 1301     AMD Radeon R5 M330  Windows 10  2.19kg        764.0       Intel
# 1302      Intel HD Graphics  Windows 10   2.2kg        369.0       Intel
#
#       Memory_Amount
# 1298            128
# 1299            512
# 1300             64
# 1301           1024
# 1302            500

# %% [markdown]
# ### 1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD/SDD/др.)

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %% [markdown]
# * 1 вариант решения

# %%
df['Memory_Type'] = df['Memory'].apply(lambda x: x.split('B')[-1])
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00       Intel
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60       Intel
#
#       Memory_Type
# 0             SSD
# 1   Flash Storage
# 2             SSD
# 3             SSD
# 4             SSD

# %%
df['Memory_Type'].value_counts()
# Out:
#  SSD              641
#  HDD              576
#  Flash Storage     74
#  Hybrid            12
# Name: Memory_Type, dtype: int64

# %% [markdown]
# * 2 вариант решения

# %%
def convert_to_type(x):
    type_memory = x.replace(' ', '').split('B')[-1]
    return type_memory

# %%
df['Memory_Type'] = df['Memory'].apply(convert_to_type)
df['Memory_Type'].value_counts()
# Out:
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: Memory_Type, dtype: int64

# %% [markdown]
# * 3 вариант решения

# %%
def Type(x):
  if len(x.split(' ')) > 3:
    memory = x.split('B') [1][:x.split('B')[1].find('+')]
    memory2 = x.split('B')[-1]
    result = memory + memory2
  else : result = x.split('B')[-1]
  result = result.lstrip().rstrip()
  return result.lstrip().rstrip()

# %%
df['Memory_Type'] = df['Memory'].apply(Type)
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00       Intel
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60       Intel
#
#    Memory_Amount    Memory_Type
# 0            128            SSD
# 1            128  Flash Storage
# 2            256            SSD
# 3            512            SSD
# 4            256            SSD

# %%
df['Memory_Type'].value_counts()
# Out:
# SSD                   637
# HDD                   374
# SSD  HDD              200
# Flash Storage          74
# Hybrid                 10
# SSD  SSD                4
# SSD  Hybrid             2
# Flash Storage  HDD      1
# HDD  HDD                1
# Name: Memory_Type, dtype: int64

# %% [markdown]
# ### 1.4 Удалите признаки Memory и ScreenResolution

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
#  12  Cpu_Company       1303 non-null   object
#  13  Memory_Amount     1303 non-null   int64
#  14  Memory_Type       1303 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 152.8+ KB

# %%
df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00       Intel
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60       Intel
#
#    Memory_Amount    Memory_Type
# 0            128            SSD
# 1            128  Flash Storage
# 2            256            SSD
# 3            512            SSD
# 4            256            SSD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   Product        1303 non-null   object
#  2   TypeName       1303 non-null   object
#  3   Inches         1303 non-null   float64
#  4   Cpu            1303 non-null   object
#  5   Ram            1303 non-null   object
#  6   Gpu            1303 non-null   object
#  7   OpSys          1303 non-null   object
#  8   Weight         1303 non-null   object
#  9   Price_euros    1303 non-null   float64
#  10  Cpu_Company    1303 non-null   object
#  11  Memory_Amount  1303 non-null   int64
#  12  Memory_Type    1303 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ### 2.1 Создайте признак SSD, который изначально равен 0

# %%
df['SSD'] = 0
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00       Intel
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60       Intel
#
#    Memory_Amount    Memory_Type  SSD
# 0            128            SSD    0
# 1            128  Flash Storage    0
# 2            256            SSD    0
# 3            512            SSD    0
# 4            256            SSD    0

# %% [markdown]
# ### 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD

# %%
df.loc[df['Memory_Type'] == 'SSD', 'SSD'] = 1
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00       Intel
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60       Intel
#
#    Memory_Amount    Memory_Type  SSD
# 0            128            SSD    1
# 1            128  Flash Storage    0
# 2            256            SSD    1
# 3            512            SSD    1
# 4            256            SSD    1

# %%
df['SSD'].value_counts()
# Out:
# 0    666
# 1    637
# Name: SSD, dtype: int64

# %% [markdown]
# ### 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %%
df['Weight'] = df['Weight'].str.replace('kg', '').astype('float')
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount    Memory_Type  SSD
# 0            128            SSD    1
# 1            128  Flash Storage    0
# 2            256            SSD    1
# 3            512            SSD    1
# 4            256            SSD    1

# %%
df['Weight'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Задание 3
# Создайте датафрейм с клиентами:
#
# ```clients = pd.DataFrame({'client_id': [45, 32, 67, 33, 43],'laptop_id': [506, 398, 710, 120, 1999]})```
#
# laptop_id - это индексы датафрейма с ноутбуками

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})
clients
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %%
clients_lap_id = clients.set_index('laptop_id')
clients_lap_id
# Out:
#            client_id
# laptop_id
# 506               45
# 398               32
# 710               67
# 120               33
# 1999              43

# %% [markdown]
# ### 3.1 Присоедините к таблице clients данные по ноутбукам через метод join

# %%
joined = clients_lap_id.join(df)
joined
# Out:
#            client_id Company                 Product     TypeName  Inches  \
# laptop_id
# 506               45    Asus  ZenBook UX510UX-CN211T     Notebook    15.6
# 398               32    Dell         Precision M5520  Workstation    15.6
# 710               67  Lenovo      Legion Y520-15IKBN       Gaming    15.6
# 120               33    Acer                  Spin 3     Notebook    15.6
# 1999              43     NaN                     NaN          NaN     NaN
#
#                                    Cpu  Ram                         Gpu  \
# laptop_id
# 506         Intel Core i7 7500U 2.7GHz  8GB       Intel HD Graphics 620
# 398        Intel Core i7 7700HQ 2.8GHz  8GB         Nvidia Quadro M1200
# 710        Intel Core i7 7700HQ 2.8GHz  8GB  Nvidia GeForce GTX 1050 Ti
# 120         Intel Core i3 7100U 2.4GHz  6GB       Intel HD Graphics 620
# 1999                               NaN  NaN                         NaN
#
#                 OpSys  Weight  Price_euros Cpu_Company  Memory_Amount  \
# laptop_id
# 506        Windows 10    2.00       1224.0       Intel          256.0
# 398        Windows 10    1.78       2712.0       Intel          256.0
# 710        Windows 10    2.50       1249.0       Intel          128.0
# 120        Windows 10    2.10        479.0       Intel         1024.0
# 1999              NaN     NaN          NaN         NaN            NaN
#
#           Memory_Type  SSD
# laptop_id
# 506          SSD  HDD  0.0
# 398               SSD  1.0
# 710          SSD  HDD  0.0
# 120               HDD  0.0
# 1999              NaN  NaN

# %% [markdown]
# ### 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами

# %%
clients
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %%
df['laptop_id'] = df.index
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount    Memory_Type  SSD  laptop_id
# 0            128            SSD    1          0
# 1            128  Flash Storage    0          1
# 2            256            SSD    1          2
# 3            512            SSD    1          3
# 4            256            SSD    1          4

# %%
merged = clients.merge(df, on='laptop_id')
merged
# Out:
#    client_id  laptop_id Company                 Product     TypeName  Inches  \
# 0         45        506    Asus  ZenBook UX510UX-CN211T     Notebook    15.6
# 1         32        398    Dell         Precision M5520  Workstation    15.6
# 2         67        710  Lenovo      Legion Y520-15IKBN       Gaming    15.6
# 3         33        120    Acer                  Spin 3     Notebook    15.6
#
#                            Cpu  Ram                         Gpu       OpSys  \
# 0   Intel Core i7 7500U 2.7GHz  8GB       Intel HD Graphics 620  Windows 10
# 1  Intel Core i7 7700HQ 2.8GHz  8GB         Nvidia Quadro M1200  Windows 10
# 2  Intel Core i7 7700HQ 2.8GHz  8GB  Nvidia GeForce GTX 1050 Ti  Windows 10
# 3   Intel Core i3 7100U 2.4GHz  6GB       Intel HD Graphics 620  Windows 10
#
#    Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 0    2.00       1224.0       Intel            256    SSD  HDD    0
# 1    1.78       2712.0       Intel            256         SSD    1
# 2    2.50       1249.0       Intel            128    SSD  HDD    0
# 3    2.10        479.0       Intel           1024         HDD    0

# %% [markdown]
# ## Задание 4
# Составьте несколько сводных таблиц

# %% [markdown]
# ### 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании производителя
# Отсортируйте от меньшей стоимости к большей

# %%
df.groupby('Company').agg({'Price_euros': 'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %% [markdown]
# ### 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора

# %%
df.groupby('Cpu_Company').agg({'Price_euros': ['min', 'mean', 'max']})
# Out:
#             Price_euros
#                     min         mean     max
# Cpu_Company
# AMD               199.0   560.638871  2199.0
# Intel             174.0  1152.214145  6099.0
# Samsung           659.0   659.000000   659.0

# %% [markdown]
# ### 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ

# %%
df.pivot_table(index='Cpu_Company', columns='Ram',
               values='Weight', aggfunc='count',
               fill_value=0)
# Out:
# Ram          12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Cpu_Company
# AMD             2     3     0    1     0   31     0   13   12
# Intel          23   197     3   21    17  343     1   28  607
# Samsung         0     0     0    0     0    1     0    0    0

# %% [markdown]
# ### 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти

# %%
df.groupby(['OpSys', 'Memory_Amount']).agg({'Price_euros': 'mean'}).fillna(0)
# Out:
#                             Price_euros
# OpSys        Memory_Amount
# Android      64              434.000000
# Chrome OS    16              305.380000
#              32              412.454545
#              64              774.333333
#              128            1275.000000
#              256            1559.000000
#              512            2199.000000
# Linux        128             742.250000
#              256             811.638125
#              500             389.056364
#              1024            581.401290
# Mac OS X     128            1099.000000
#              256            1311.994000
#              512            1222.000000
# No OS        128             562.140000
#              256             782.989286
#              500             404.675385
#              512            1098.500000
#              1024            540.539600
#              2048            594.000000
# Windows 10   8              2249.000000
#              32              270.001471
#              64              499.716000
#              128            1026.489167
#              180            1073.500000
#              240            3100.000000
#              256            1334.456872
#              500             664.717647
#              512            1911.985285
#              1024            904.827906
#              2048            666.947500
# Windows 10 S 64              308.995000
#              128            1039.000000
#              256            1668.950000
#              512            2589.000000
# Windows 7    128            1320.323333
#              180            1199.000000
#              256            1846.466800
#              500             924.048333
#              508            1002.000000
#              512            2235.396667
#              1024           1539.666667
# macOS        128            1119.315000
#              256            1600.370000
#              512            2180.870000

# %%
df.pivot_table(index='OpSys', columns='Memory_Amount',
               values='Price_euros', aggfunc='mean',
               fill_value=0)
# Out:
# Memory_Amount  8       16          32          64           128     180   \
# OpSys
# Android           0    0.00    0.000000  434.000000     0.000000     0.0
# Chrome OS         0  305.38  412.454545  774.333333  1275.000000     0.0
# Linux             0    0.00    0.000000    0.000000   742.250000     0.0
# Mac OS X          0    0.00    0.000000    0.000000  1099.000000     0.0
# No OS             0    0.00    0.000000    0.000000   562.140000     0.0
# Windows 10     2249    0.00  270.001471  499.716000  1026.489167  1073.5
# Windows 10 S      0    0.00    0.000000  308.995000  1039.000000     0.0
# Windows 7         0    0.00    0.000000    0.000000  1320.323333  1199.0
# macOS             0    0.00    0.000000    0.000000  1119.315000     0.0
#
# Memory_Amount  240          256         500   508          512          1024  \
# OpSys
# Android           0     0.000000    0.000000     0     0.000000     0.000000
# Chrome OS         0  1559.000000    0.000000     0  2199.000000     0.000000
# Linux             0   811.638125  389.056364     0     0.000000   581.401290
# Mac OS X          0  1311.994000    0.000000     0  1222.000000     0.000000
# No OS             0   782.989286  404.675385     0  1098.500000   540.539600
# Windows 10     3100  1334.456872  664.717647     0  1911.985285   904.827906
# Windows 10 S      0  1668.950000    0.000000     0  2589.000000     0.000000
# Windows 7         0  1846.466800  924.048333  1002  2235.396667  1539.666667
# macOS             0  1600.370000    0.000000     0  2180.870000     0.000000
#
# Memory_Amount      2048
# OpSys
# Android          0.0000
# Chrome OS        0.0000
# Linux            0.0000
# Mac OS X         0.0000
# No OS          594.0000
# Windows 10     666.9475
# Windows 10 S     0.0000
# Windows 7        0.0000
# macOS            0.0000

# %% [markdown]
# ## Задание 5*
# Ответьте на несколько вопросов

# %% [markdown]
# ### 5.1 Ноутбуков каких компаний и с каким процессором больше?

# %%
note = pd.crosstab(index=df['Company'], columns=df['Cpu_Company'])
note
# Out:
# Cpu_Company  AMD  Intel  Samsung
# Company
# Acer          10     93        0
# Apple          0     21        0
# Asus          11    147        0
# Chuwi          0      3        0
# Dell           0    297        0
# Fujitsu        0      3        0
# Google         0      3        0
# HP            25    249        0
# Huawei         0      2        0
# LG             0      3        0
# Lenovo        16    281        0
# MSI            0     54        0
# Mediacom       0      7        0
# Microsoft      0      6        0
# Razer          0      7        0
# Samsung        0      8        1
# Toshiba        0     48        0
# Vero           0      4        0
# Xiaomi         0      4        0

# %%
note.max().max()
# Out:
# 297

# %% [markdown]
# ### 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %%
lap = pd.crosstab(index=df['Memory_Type'], columns=df['Memory_Amount'])
lap
# Out:
# Memory_Amount       8     16    32    64    128   180   240   256   500   \
# Memory_Type
# Flash Storage          0     7    38    15     4     0     0     8     0
# Flash Storage  HDD     0     0     0     1     0     0     0     0     0
# HDD                    0     0     1     0     1     0     0     0   132
# HDD  HDD               0     0     0     0     0     0     0     0     0
# Hybrid                 0     0     0     0     0     0     0     0     0
# SSD                    1     3     6     1    76     5     1   412     0
# SSD  HDD               0     0     0     0    96     0     0    85     0
# SSD  Hybrid            0     0     0     0     0     0     0     1     0
# SSD  SSD               0     0     0     0     0     0     0     2     0
#
# Memory_Amount       508   512   1024  2048
# Memory_Type
# Flash Storage          0     2     0     0
# Flash Storage  HDD     0     0     0     0
# HDD                    0     0   224    16
# HDD  HDD               0     0     1     0
# Hybrid                 1     0     9     0
# SSD                    0   118    14     0
# SSD  HDD               0    17     2     0
# SSD  Hybrid            0     1     0     0
# SSD  SSD               0     2     0     0

# %%
lap.max().max()
# Out:
# 412
